# %%
# !pip install fastapi uvicorn pyngrok huggingface_hub numpy -q

# %%
from huggingface_hub import snapshot_download
snapshot_download(
    repo_id="pisha2410/ufdr-indexes",
    repo_type="dataset",
    local_dir="/content/data",
    ignore_patterns=["*.md", ".gitattributes", "user_index_split/*"]
)
print("Done!")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Fetching ... files: 0it [00:00, ?it/s]
# Done!

# %%
# !git clone https://github.com/prisha2410/ufdr-copilot.git /content/ufdr-copilot
# Out:
# Cloning into '/content/ufdr-copilot'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 163 (delta 81), reused 124 (delta 45), pack-reused 0 (from 0)
# Receiving objects: 100% (163/163), 56.11 KiB | 11.22 MiB/s, done.
# Resolving deltas: 100% (81/81), done.

# %%
import os
os.environ["PAGEINDEX_STORE"] = "/content/data/pageindex_store"
os.environ["PAGEINDEX_DIR"]   = "/content/data/pageindex_data"
os.environ["FAISS_DIR"]       = "/content/data/faiss_index"

# Restore original full server
import subprocess, threading, time
server = subprocess.Popen(["python", "api/server.py"], cwd="/content/ufdr-copilot")
time.sleep(5)
print("Server started!")
# Out:
# Server started!

# %%
from pyngrok import ngrok

ngrok.set_auth_token("2iPeqGpOMa1N3OOpywgKdI942id_Lfwqc4oi9ggWQNEFFX35")
url = ngrok.connect(8000)
print(f"\n✅ API URL: {url}")
print(f"✅ Docs: {url}/docs")
# Out:
# ✅ API URL: NgrokTunnel: "https://9d9c-34-85-195-198.ngrok-free.app" -> "http://localhost:8000"
# ✅ Docs: NgrokTunnel: "https://9d9c-34-85-195-198.ngrok-free.app" -> "http://localhost:8000"/docs
